# %%
#EDA processs : Exploratory Data Analysis : means cleaning process
#to clean given data 
#use dataset automobile_data.csv
#import all basic library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# to read the csv file
df = pd.read_csv("Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# To get the first 10 readings
df.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Hiw many rows and columns are there in dataset we use shape function
df.shape
# Out:
# (205, 26)

# %%
# To check null values
df.isnull()
# Out:
#      symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0        False              False  False      False       False         False
# 1        False              False  False      False       False         False
# 2        False              False  False      False       False         False
# 3        False              False  False      False       False         False
# 4        False              False  False      False       False         False
# ..         ...                ...    ...        ...         ...           ...
# 200      False              False  False      False       False         False
# 201      False              False  False      False       False         False
# 202      False              False  False      False       False         False
# 203      False              False  False      False       False         False
# 204      False              False  False      False       False         False
#
# ...

# %%
# To get count of null values
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Visualization of null values
# heat map for all columns in dataset
# isnull gives null values 
# we can see the visualization of null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# To check the data types of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# To check the data types of the columns using dtypes gives us only the data type whereas 
# info() gives us not null count and the indexing
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# To get the sample of how the data looks in dataset we take random sample of data
df.sample(5)
# Out:
#      symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 90           1               128  nissan    diesel        std          two
# 104          3               194  nissan       gas        std          two
# 108          0               161  peugot    diesel      turbo         four
# 195         -1                74   volvo       gas        std         four
# 95           1               128  nissan       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 90       sedan          fwd           front        94.5  ...          103
# 104  hatchback          rwd           front        91.3  ...          181
# 108      sedan          rwd           front       107.9  ...          152
# 195      wagon          rwd           front       104.3  ...          141
# 95   hatchback          fwd           front        94.5  ...           97
#
# ...

# %%
# To get the unique values from the particular column
df["normalized-losses"].unique()
# Out:
# array(['?', '164', '158', '192', '188', '121', '98', '81', '118', '148',
#        '110', '145', '137', '101', '78', '106', '85', '107', '104', '113',
#        '150', '129', '115', '93', '142', '161', '153', '125', '128',
#        '122', '103', '168', '108', '194', '231', '119', '154', '74',
#        '186', '83', '102', '89', '87', '77', '91', '134', '65', '197',
#        '90', '94', '256', '95'], dtype=object)

# %%
# To get the count of unqiue values we use value_counts()
df["normalized-losses"].value_counts()
# Out:
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64

# %%
# to replace the ? in normalized losses cloumn with null values permanently
df["normalized-losses"].replace("?",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
# Now to change the datatype of normalized losses column to float
df["normalized-losses"]=df["normalized-losses"].astype("float")

# %%
# To check wether the datatype has changed
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# we can see the visualization of null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# To find the percentage of null values
df.isnull().sum()/df.shape[0]*100
# Out:
# symboling             0.0
# normalized-losses    20.0
# make                  0.0
# fuel-type             0.0
# aspiration            0.0
# num-of-doors          0.0
# body-style            0.0
# drive-wheels          0.0
# engine-location       0.0
# wheel-base            0.0
# length                0.0
# width                 0.0
# height                0.0
# curb-weight           0.0
# engine-type           0.0
# num-of-cylinders      0.0
# engine-size           0.0
# fuel-system           0.0
# bore                  0.0
# stroke                0.0
# compression-ratio     0.0
# horsepower            0.0
# peak-rpm              0.0
# city-mpg              0.0
# highway-mpg           0.0
# price                 0.0
# dtype: float64

# %%
# To fill the null values in normalized losses column with the mean of normalized losses column permanently
# we use fillna() function
# First we find the mean or average of the normalized losses column
m = df["normalized-losses"].mean()
df["normalized-losses"].fillna(m,inplace=True)
# To check the null values in normalized losses column
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# To get the count of unqiue values we use value_counts()
df["horsepower"].value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 62      6
# 101     6
# 160     6
# 114     6
# 84      5
# 97      5
# 102     5
# 145     5
# 82      5
# 76      5
# 111     4
# 92      4
# 123     4
# 86      4
# 90      3
# 73      3
# 85      3
# 207     3
# 182     3
# 121     3
# 152     3
# 112     2
# 56      2
# 161     2
# 156     2
# 94      2
# 52      2
# ?       2
# 162     2
# 155     2
# 184     2
# 100     2
# 176     2
# 55      1
# 262     1
# 134     1
# 115     1
# 140     1
# 48      1
# 58      1
# 60      1
# 78      1
# 135     1
# 200     1
# 64      1
# 120     1
# 72      1
# 154     1
# 288     1
# 143     1
# 142     1
# 175     1
# 106     1
# Name: count, dtype: int64

# %%
# to replace the ? in horsepower cloumn with null values permanently
df["horsepower"].replace("?",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# Now to change the datatype of horsepower column to float
df["horsepower"]=df["horsepower"].astype("float")

# %%
# To check wether the datatype has changed
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# we can see the visualization of null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# To find the percentage of null values
df.isnull().sum()/df.shape[0]*100
# Out:
# symboling            0.00000
# normalized-losses    0.00000
# make                 0.00000
# fuel-type            0.00000
# aspiration           0.00000
# num-of-doors         0.00000
# body-style           0.00000
# drive-wheels         0.00000
# engine-location      0.00000
# wheel-base           0.00000
# length               0.00000
# width                0.00000
# height               0.00000
# curb-weight          0.00000
# engine-type          0.00000
# num-of-cylinders     0.00000
# engine-size          0.00000
# fuel-system          0.00000
# bore                 0.00000
# stroke               0.00000
# compression-ratio    0.00000
# horsepower           0.97561
# peak-rpm             0.00000
# city-mpg             0.00000
# highway-mpg          0.00000
# price                0.00000
# dtype: float64

# %%
# To fill the null values in horsepower column with the mean of horsepower column permanently
# we use fillna() function
# First we find the mean or average of the horsepower column
m = df["horsepower"].mean()
df["horsepower"].fillna(m,inplace=True)
# To check the null values in horsepower column
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# To get the count of unqiue values we use value_counts()
df["price"].value_counts()
# Out:
# price
# ?        4
# 8921     2
# 18150    2
# 8845     2
# 8495     2
#         ..
# 45400    1
# 16503    1
# 5389     1
# 6189     1
# 22625    1
# Name: count, Length: 187, dtype: int64

# %%
# to replace the ? in price cloumn with null values permanently
df["price"].replace("?",np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
# Now to change the datatype of price column to float
df["price"]=df["price"].astype("float")

# %%
# To check wether the datatype has changed
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower           float64
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# we can see the visualization of null values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# To find the percentage of null values
df.isnull().sum()/df.shape[0]*100
# Out:
# symboling            0.00000
# normalized-losses    0.00000
# make                 0.00000
# fuel-type            0.00000
# aspiration           0.00000
# num-of-doors         0.00000
# body-style           0.00000
# drive-wheels         0.00000
# engine-location      0.00000
# wheel-base           0.00000
# length               0.00000
# width                0.00000
# height               0.00000
# curb-weight          0.00000
# engine-type          0.00000
# num-of-cylinders     0.00000
# engine-size          0.00000
# fuel-system          0.00000
# bore                 0.00000
# stroke               0.00000
# compression-ratio    0.00000
# horsepower           0.00000
# peak-rpm             0.00000
# city-mpg             0.00000
# highway-mpg          0.00000
# price                1.95122
# dtype: float64

# %%
# To fill the null values in price column with the mean of price column permanently
# we use fillna() function
# First we find the mean or average of the price column
m = df["price"].mean()
df["price"].fillna(m,inplace=True)
# To check the null values in price column
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
# To check the outliers in given dataset
# Here output variable means target=price(countinous numeric)
# use boxplot
sns.boxplot(data=df,x="price")
# Out:
# <Axes: xlabel='price'>

# %%
# To get the count of unqiue values we use value_counts()
df["make"].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
# To check the outliers in given dataset
# Here output variable means target=price(countinous numeric)
# use boxplot
sns.boxplot(data=df,x="price",y="make")
# Out:
# <Axes: xlabel='price', ylabel='make'>

# %%
# To check the outliers in given dataset
# Here output variable means target=price(countinous numeric)
# use boxplot
sns.boxplot(data=df,x="horsepower")
# Out:
# <Axes: xlabel='horsepower'>

# %%
# To check the outliers in given dataset
# Here output variable means target=price(countinous numeric)
# use boxplot
sns.boxplot(data=df,x="horsepower",y="make")
# Out:
# <Axes: xlabel='horsepower', ylabel='make'>

# %%
# To check the outliers in given dataset
# Here output variable means target=price(countinous numeric)
# use boxplot
sns.boxplot(data=df,x="horsepower",y="price")
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>
